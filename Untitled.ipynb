# %%
import requests
import pandas as pd

# %% [markdown]
# 1. get list of exercise

# %% [markdown]
# - sort excercise by type
# - define rules to group exercise by type of training-
# - define rules to match exercerise together

# %% [markdown]
# 2. ask users question
# - experience
# - goal
# - nb of days
# - access to materials

# %%
url = "https://wger.de/api/v2/exercisebaseinfo/?language=2&limit=2000"
data = requests.get(url)

# %%
len(df_exercise)
# Out:
# 316

# %%
all_exercise = data.json()
df_muscle = pd.DataFrame(data = all_exercise['results'])
df_muscle.to_csv('list_exerciseBase.csv')

# %% [markdown]
# ## -----

# %% [markdown]
# 3. create api that requests data

# %%
df_base = pd.read_csv('list_exerciseBase.csv',index_col=0)
df_base.head()
# Out:
#    id                                  uuid                         category  \
# 0   9  1b020b3a-3732-4c7e-92fd-a0cec90ed69b        {'id': 10, 'name': 'Abs'}
# 1  12  53906cd1-61f1-4d56-ac60-e4fcc5824861        {'id': 9, 'name': 'Legs'}
# 2  13  49859097-644a-417a-8cb7-491b7d8bc383        {'id': 9, 'name': 'Legs'}
# 3  20  f24cb758-9c0d-42d4-ad9e-6025c527dd13  {'id': 13, 'name': 'Shoulders'}
# 4  22  80d6017d-58a1-4061-8fa2-0d08b9886523        {'id': 9, 'name': 'Legs'}
#
#                                              muscles  \
# 0                                                 []
# 1  [{'id': 8, 'name': 'Gluteus maximus', 'is_fron...
# 2                                                 []
# 3                                                 []
# 4  [{'id': 10, 'name': 'Quadriceps femoris', 'is_...
#
#                                    muscles_secondary  \
# 0                                                 []
# 1  [{'id': 11, 'name': 'Biceps femoris', 'is_fron...
# 2                                                 []
# 3                                                 []
# 4  [{'id': 8, 'name': 'Gluteus maximus', 'is_fron...
#
#                             equipment  \
# 0  [{'id': 10, 'name': 'Kettlebell'}]
# 1                                  []
# 2                                  []
# 3     [{'id': 3, 'name': 'Dumbbell'}]
# 4                                  []
#
#                                              license  license_author images  \
# 0  {'id': 2, 'full_name': 'Creative Commons Attri...    deusinvictus     []
# 1  {'id': 1, 'full_name': ' Creative Commons Attr...           flori     []
# 2  {'id': 1, 'full_name': ' Creative Commons Attr...          Marius     []
# 3  {'id': 1, 'full_name': ' Creative Commons Attr...          trzr23     []
# 4  {'id': 2, 'full_name': 'Creative Commons Attri...  Tetsuhiko Asai     []
#
#                                            exercises  variations
# 0  [{'id': 345, 'uuid': 'c788d643-150a-4ac7-97ef-...         NaN
# 1  [{'id': 174, 'uuid': '99881bdd-43d7-4c3b-82ed-...         NaN
# 2  [{'id': 223, 'uuid': 'e56d0a17-b1b8-427d-991e-...         NaN
# 3  [{'id': 228, 'uuid': '880bff63-6798-4ffc-a818-...         5.0
# 4  [{'id': 353, 'uuid': '583281c7-2362-48e7-95d5-...         NaN

# %%
df_muscle = pd.read_csv('list_muscles.csv',index_col=0)
df_muscle.head()
# Out:
#    id              name  is_front                             image_url_main  \
# 0   2  Anterior deltoid      True   /static/images/muscles/main/muscle-2.svg
# 1   1    Biceps brachii      True   /static/images/muscles/main/muscle-1.svg
# 2  11    Biceps femoris     False  /static/images/muscles/main/muscle-11.svg
# 3  13        Brachialis      True  /static/images/muscles/main/muscle-13.svg
# 4   7     Gastrocnemius     False   /static/images/muscles/main/muscle-7.svg
#
#                               image_url_secondary
# 0   /static/images/muscles/secondary/muscle-2.svg
# 1   /static/images/muscles/secondary/muscle-1.svg
# 2  /static/images/muscles/secondary/muscle-11.svg
# 3  /static/images/muscles/secondary/muscle-13.svg
# 4   /static/images/muscles/secondary/muscle-7.svg

# %%
df_exercise = pd.read_csv('list_exercises.csv',index_col=0)
df_exercise.set_index('id',inplace=True)
df_exercise.head()
# Out:
#                                      uuid                       name  \
# id
# 345  c788d643-150a-4ac7-97ef-84643c6419bf  2 Handed Kettlebell Swing
# 227  53ca25b3-61d9-4f72-bfdb-492b83484ff5      Arnold Shoulder Press
# 289  6add5973-86d0-4543-928a-6bb8b3f34efc                   Axe Hold
# 637  0fd6154d-fb53-4b24-acc0-1c5c05b57ebc                 Back Squat
# 343  1b9dc5bc-790b-4e21-a55d-f8b3115e94c5         Barbell Ab Rollout
#
#      exercise_base  status                                        description  \
# id
# 345              9       2   <p>Two Handed Russian Style Kettlebell swing</p>
# 227             20       2  <p>Very common shoulder exercise.</p>\n<p> </p...
# 289             31       2  <p>Grab dumbbells and extend arms to side and ...
# 637             34       2  <p>Place a barbell in a rack just below should...
# 343             41       2  <p>Place a barbell on the floor at your feet.<...
#
#     creation_date  category muscles muscles_secondary equipment  language  \
# id
# 345    2015-08-03        10      []                []      [10]         2
# 227    2014-03-09        13      []                []       [3]         2
# 289    2014-11-02         8      []                []       [3]         2
# 637    2019-05-29         9      []                []        []         2
# 343    2015-07-27        10    [14]                []       [1]         2
#
#      license license_author                                variations
# id
# 345        2   deusinvictus                                        []
# 227        1         trzr23  [227, 329, 229, 190, 119, 123, 152, 155]
# 289        1     GrosseHund                                        []
# 637        2           axel                                        []
# 343        2          sevae                                        []

# %%
df_exercise[df_exercise['name'] == 'Bench Press']
# Out:
#                                      uuid         name  exercise_base  status  \
# id
# 192  5da6340b-22ec-4c1b-a443-eef2f59f92f0  Bench Press             73       2
#
#                                            description creation_date  \
# id
# 192  <p>Lay down on a bench, the bar should be dire...    2013-08-11
#
#      category muscles muscles_secondary equipment  language  license  \
# id
# 192        11     [4]            [2, 5]    [1, 8]         2        1
#
#     license_author                                variations
# id
# 192        sistab2  [192, 100, 101, 163, 210, 211, 270, 399]

# %%
df_exercise.loc[192]
# Out:
# uuid                              5da6340b-22ec-4c1b-a443-eef2f59f92f0
# name                                                       Bench Press
# exercise_base                                                       73
# status                                                               2
# description          <p>Lay down on a bench, the bar should be dire...
# creation_date                                               2013-08-11
# category                                                            11
# muscles                                                            [4]
# muscles_secondary                                               [2, 5]
# equipment                                                       [1, 8]
# language                                                             2
# license                                                              1
# license_author                                                 sistab2
# variations                    [192, 100, 101, 163, 210, 211, 270, 399]
# Name: 192, dtype: object

# %%
df_image[df_image.exercise_base == 73]
# Out:
#                                     uuid  exercise_base  \
# id
# 68  08517378-bc36-4f6b-9952-1f45a02d936e             73
# 70  41e5c58e-0325-4620-8d96-7372cc4dae8c             73
#
#                                                 image  is_main  status  style
# id
# 68  https://wger.de/media/exercise-images/192/Benc...     True       2      1
# 70  https://wger.de/media/exercise-images/192/Benc...    False       2      1

# %%
df_image = pd.read_csv('list_images.csv',index_col=0)
df_image.set_index('id',inplace=True)
df_image.head()
# Out:
#                                     uuid  exercise_base  \
# id
# 3   ef0b00e2-3323-4e7f-88fe-d71ef34b3384            167
# 7   bed4f21b-28be-4ef1-bd88-1a4e3db66c5c            427
# 11  59efcec2-a7ce-40ba-bf2b-1a6eabe52fbd            301
# 15  1c37e4e1-5144-4a50-8294-16180a9bc767             76
# 19  065f9418-6245-46ae-8e24-b4013ce084e4             95
#
#                                                 image  is_main  status  style
# id
# 3   https://wger.de/media/exercise-images/91/Crunc...     True       2      1
# 7   https://wger.de/media/exercise-images/93/Decli...     True       2      1
# 11  https://wger.de/media/exercise-images/128/Hype...     True       2      1
# 15  https://wger.de/media/exercise-images/88/Narro...     True       2      1
# 19  https://wger.de/media/exercise-images/129/Stan...     True       2      1

# %%
df_image.loc[227].image
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 227
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-1b6347881a8d> in <module>()
# ----> 1 df_image.loc[227].image
#
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3486             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3487         else:
# -> 3488             loc = self.index.get_loc(key)
#    3489
#    3490             if isinstance(loc, np.ndarray):
#
# /Users/tomborg/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 227
